# %%
#   ______                                       ___     
#  /\__  _\                                    /'___`\   
#  \/_/\ \/    __     _ __    __     __       /\_\ /\ \  
#     \ \ \  /'__`\  /\`'__\/'__`\ /'__`\     \/_/// /__ 
#      \ \ \/\ \L\.\_\ \ \//\  __//\ \L\.\_      // /_\ \
#       \ \_\ \__/.\_\\ \_\\ \____\ \__/.\_\    /\______/
#        \/_/\/__/\/_/ \/_/ \/____/\/__/\/_/    \/_____/ 
#

# %%
import numpy as np
import matplotlib.pyplot as plt
from casadi import *

# %% [markdown]
# ## Punto 1.

# %%
x_1 = np.linspace(-1, 31, 5000)
y_1 = np.linspace(-2, 36, 5000)

x, y = np.meshgrid(x_1, y_1)
f = 5*exp(-0.01*((x-15)**2 + (y-20)**2)) - 2*exp(-0.08*((x-20)**2 + (y-15)**2)) + 3*exp(-0.08*((x-25)**2 + (y-10)**2)) + 2*exp(-0.1*((x-10)**2 + (y-10)**2)) - 2*exp(-0.5*((x-5)**2 + (y-10)**2)) - 4*exp(-0.1*((x-15)**2 + (y-5)**2)) - 2*exp(-0.5*((x-8)**2 + (y-25)**2)) - 2*exp(-0.5*((x-21)**2 + (y-25)**2)) + 2*exp(-0.5*((x-25)**2 + (y-16)**2)) + 2*exp(-0.5*((x-5)**2 + (y-14)**2))

# %%
plt.contourf(x, y, f, levels=25, cmap="inferno")
plt.colorbar(label='f(x, y)')

# %%
opti = Opti()
x1 = opti.variable()
y1 = opti.variable()
f_ = 5*exp(-0.01*((x1-15)**2 + (y1-20)**2)) - 2*exp(-0.08*((x1-20)**2 + (y1-15)**2)) + 3*exp(-0.08*((x1-25)**2 + (y1-10)**2)) + 2*exp(-0.1*((x1-10)**2 + (y1-10)**2)) - 2*exp(-0.5*((x1-5)**2 + (y1-10)**2)) - 4*exp(-0.1*((x1-15)**2 + (y1-5)**2)) - 2*exp(-0.5*((x1-8)**2 + (y1-25)**2)) - 2*exp(-0.5*((x1-21)**2 + (y1-25)**2)) + 2*exp(-0.5*((x1-25)**2 + (y1-16)**2)) + 2*exp(-0.5*((x1-5)**2 + (y1-14)**2))


initial = [(15,20),(25,10),(25,16),(10,10),(5,14)]
valores = []


opti.minimize(-f_)
opti.solver('sqpmethod')
opti.subject_to(x1>=-1)
opti.subject_to(31>=x1)
opti.subject_to(y1>=-2)
opti.subject_to(36>=y1)

for i in initial:
    xi, yi = i
    opti.set_initial(x1, xi)
    opti.set_initial(y1, yi)
    sol = opti.solve()
    valores.append((sol.value(x1),sol.value(y1)))
# Out:
# qpOASES -- An Implementation of the Online Active Set Strategy.
# Copyright (C) 2007-2015 by Hans Joachim Ferreau, Andreas Potschka,
# Christian Kirches et al. All rights reserved.
#
# qpOASES is distributed under the terms of the
# GNU Lesser General Public License 2.1 in the hope that it will be
# useful, but WITHOUT ANY WARRANTY; without even the implied warranty
# of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
# See the GNU Lesser General Public License for more details.
#
# -------------------------------------------
# This is casadi::Sqpmethod.
# Using exact Hessian
# Number of variables:                               2
# Number of constraints:                             4
# Number of nonzeros in constraint Jacobian:         4
# Number of nonzeros in Lagrangian Hessian:          4
#
# iter      objective    inf_pr    inf_du     ||d||  lg(rg) ls    info
#    0  -4.963377e+00  0.00e+00  2.93e-02  0.00e+00       -  0  -
#
#
# ####################   qpOASES  --  QP NO.   1   #####################
#
#     Iter   |    StepLength    |       Info       |   nFX   |   nAC
#  ----------+------------------+------------------+---------+---------
#        0   |   3
#####################
#
#     Iter   |    StepLength    |       Info       |   nFX   |   nAC
#  ----------+------------------+------------------+---------+---------
#        0   |   1.000000e+00   |    QP SOLVED     |     0   |     0
#    1  -3.566651e+00  0.00e+00  2.56e-02  8.50e-01       -  1  -
#
#
# ####################   qpOASES  --  QP NO.   9   #####################
#
#     Iter   |    StepLength    |       Info       |   nFX   |   nAC
#  ----------+------------------+------------------+---------+---------
#        0   |   1.000000e+00   |    QP SOLVED     |     0   |     0
#    2  -3.568061e+00  0.00e+00  8.95e-04  9.22e-02       -  1  -
#
#
# ####################   qpOASES  --  QP NO.  10   #####################
#
#     Iter   |    StepLength    |       Info       |   nFX   |   nAC
#  ----------+------------------+------------------+---------+---------
#        0   |   1.000000e+00   |    QP SOLVED     |     0   |     0
#    3  -3.568063e+00  0.00e+00  1.36e-06  3.50e-03       -  1  -
#
#
# ####################   qpOASES  --  QP NO.  11   #####################
#
#     Iter   |    StepLength    |       Info       |   nFX   |   nAC
#  ----------+------------------+------------------+---------+---------
#        0   |   1.000000e+00   |    QP SOLVED     |     0   |     0
#    4  -3.568063e+00  0.00e+00  3.21e-12  5.35e-06       -  1  -
# MESSAGE(sqpmethod): Convergence achieved after 4 iterations
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#           QP  |  95.00us ( 23.75us)  94.41us ( 23.60us)         4
#   linesearch  |  26.00us (  6.50us)  27.12us (  6.78us)         4
#       nlp_fg  |  57.00us (  5.18us)  58.95us (  5.36us)        11
#   nlp_hess_l  | 168.00us ( 15.27us) 169.68us ( 15.43us)        11
#   nlp_jac_fg  | 153.00us ( 10.20us) 198.53us ( 13.24us)        15
#        total  | 310.00us (310.00us) 308.68us (308.68us)         1
# iter      objective    inf_pr    inf_du     ||d||  lg(rg) ls    info
#    0  -3.315778e+00  0.00e+00  2.90e-01  0.00e+00       -  0  -
#
#
# ####################   qpOASES  --  QP NO.  12   #####################
#
#     Iter   |    StepLength    |       Info       |   nFX   |   nAC
#  ----------+------------------+------------------+---------+---------
#        0   |   1.000000e+00   |    QP SOLVED     |     0   |     0
#    1  -3.341786e+00  0.00e+00  3.83e-03  1.49e-01       -  1  -
#
#
# ####################   qpOASES  --  QP NO.  13   #####################
#
#     Iter   |    StepLength    |       Info       |   nFX   |   nAC
#  ----------+------------------+------------------+---------+---------
#        0   |   1.000000e+00   |    QP SOLVED     |     0   |     0
#    2  -3.341790e+00  0.00e+00  2.17e-06  2.05e-03       -  1  -
#
#
# ####################   qpOASES  --  QP NO.  14   #####################
#
#     Iter   |    StepLength    |       Info       |   nFX   |   nAC
#  ----------+------------------+------------------+---------+---------
#        0   |   1.000000e+00   |    QP SOLVED     |     0   |     0
#    3  -3.341790e+00  0.00e+00  7.00e-13  1.16e-06       -  1  -
# MESSAGE(sqpmethod): Convergence achieved after 3 iterations
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#           QP  |  73.00us ( 24.33us)  72.45us ( 24.15us)         3
#   linesearch  |  23.00us (  7.67us)  20.73us (  6.91us)         3
#       nlp_fg  |  70.00us (  5.00us)  73.33us (  5.24us)        14
#   nlp_hess_l  | 209.00us ( 14.93us) 208.27us ( 14.88us)        14
#   nlp_jac_fg  | 185.00us (  9.74us) 228.65us ( 12.03us)        19
#        total  | 234.00us (234.00us) 233.33us (233.33us)         1

# %%
print(valores)
plt.contourf(x, y, f, levels=25, cmap="inferno")
plt.colorbar(label='f(x, y)')
for val in valores:
    plt.scatter(val[0], val[1], marker='x', color='black', s=12)
# Out:
# [(14.78471507565251, 20.215098377726218), (24.779908445161595, 10.220207209839627), (24.946150398624543, 16.003689398918638), (10.417425350184978, 10.946127704918585), (5.151029151928393, 14.066188866197285)]

# %% [markdown]
# ## Punto 2.

# %% [markdown]
# ## Punto 3.

# %%
gamma1 = gamma2 = 0.4
A1 = A2 = 50.27
A3 = A4 = 28.27
a1 = 0.233
a2 = 0.242
a3 = a4 = 9.127
g = 9.8*10**2 #cm/s

# %%
N = 20
dt = 3

nx = 4
nu = 2

x = MX.sym('x', nx)
u = MX.sym('u', nu)

func = vertcat(-(a1/A1)*sqrt(fmax(2*g*x[0],0.001))+a3/A1*sqrt(fmax(2*g*x[2],0.001))+gamma1/A1*u[0],
               -(a2/A2)*sqrt(fmax(2*g*x[1],0.001))+a4/A2*sqrt(fmax(2*g*x[3],0.001))+gamma2/A2*u[1],
               -(a3/A4)*sqrt(fmax(2*g*x[2],0.001))+(1-gamma2)/A3*u[1],
               -(a4/A4)*sqrt(fmax(2*g*x[3],0.001))+(1-gamma1)/A4*u[0])
f = Function('f', [x, u], [func])

# Integrator
intg_options = dict()
intg_options['number_of_finite_elements'] = 1
intg_options['tf'] = dt
# Runge Kutta implementation with casadi
intg = integrator('intg', 'rk', {'x':x,'p': u, 'ode': f(x,u)}, intg_options)
res = intg(x0 = x, p = u)
# Discretized (sampling time dt ) System dynamics as a Casadi Function.
F = Function('F', [x, u], [res['xf']])

opti = Opti()
# Variables de desición
X = opti.variable(nx, N+1)
U = opti.variable(N, nu)
# Nombrar los estados
h1 = X[0,:]
h2 = X[1,:]
h3 = X[2,:]
h4 = X[3,:]
# Nombrar las acciones de control
u1 = U[:,0]
u2 = U[:,1]

x0 = opti.parameter(nx)

for k in range(N):
    opti.subject_to(X[:,k+1] == F(X[:,k],U[k,:]))
# # Condición inicial
opti.subject_to(X[:,0] == x0)
# Restricciones
opti.subject_to(u1<60)
opti.subject_to(u2<60)

xr =np.array([13.98,14.06,14.25,21.42])
Q1 = 3
Q2 = 3
Q3 = 0.03
Q4 = 0.03

R1 = 0.0033
R2 = 0.0033

opti.minimize( (Q1* sumsqr(h1-xr[0])+ Q2*sumsqr(h2-xr[1])+ Q3*sumsqr(h3-xr[2])+  Q4*sumsqr(h4-xr[3]))+ (R1*sumsqr(u1)+ R2*sumsqr(u2)))
opti.set_value(x0,vertcat(2,2,2,2))
# Solver
options = dict()
#options["print_time"] = False
# options["expand"] = True # La evualuacion de las funciones es mas rapido a costa de memoria
opti.solver('ipopt',options)
sol = opti.solve()
# Función que haga los pasos del MPC
mpc_step = opti.to_function('mpc_step',[x0, opti.x, opti.lam_g],[U[0,:], opti.x, opti.lam_g])
u = sol.value(U[0,:])
x = sol.value(opti.x)
lam = sol.value(opti.lam_g)

k = 40
x_history = DM.zeros(nx,k)
u_history = DM.zeros(nu,k)
current_x = vertcat(2,2,2,2)

for i in range(k):
    u_history[:,i] = u
    x_history[:,i] = current_x

    current_x = F(current_x,u)
    [u,x,lam] = mpc_step(current_x,x,lam)

plt.figure()
plt.title("Estados del sistema")
plt.ylabel("Estados ")
plt.xlabel("Tiempo discreto [k] ")
plt.plot(x_history.T)
location = 0
legend_drawn_flag = True
plt.legend(["h1", "h2", "h3","h4"], loc=0, frameon=legend_drawn_flag)
plt.grid()
plt.show()

plt.figure()
plt.plot(u_history.T)
plt.title('Señal de control')
plt.ylabel('Control u[k]')
plt.xlabel('Tiempo discreto [k]')
plt.legend(["$u_1$", "$u_2$"], loc=0, frameon=legend_drawn_flag)
plt.grid()
plt.show()
